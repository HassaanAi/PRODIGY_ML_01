# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv("housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.dropna(inplace =True)

# %%
from sklearn.model_selection import train_test_split
X=df.drop(['median_house_value'],axis=1)
y=df['median_house_value']

# %%
X_train, X_test,y_train , y_test=train_test_split(X,y,test_size=0.2)

# %%
train_data=X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19333    -122.72     38.58                 4.0       7042.0          1100.0
# 6727     -118.12     34.12                52.0       2907.0           317.0
# 5280     -118.48     34.05                48.0       3623.0           528.0
# 1079     -121.82     39.73                44.0       2923.0           659.0
# 9247     -120.07     36.97                28.0       1563.0           403.0
# ...          ...       ...                 ...          ...             ...
# 19221    -122.71     38.46                23.0       3220.0           603.0
# 16379    -121.30     38.02                16.0       2717.0           621.0
# 13344    -117.64     34.05                32.0       1129.0           251.0
# 9027     -118.88     34.02                19.0      15990.0          2611.0
# 13674    -117.27     34.05                34.0       1703.0           395.0
#
#        population  households  median_income ocean_proximity  \
# 19333      2936.0      1043.0         5.0555       <1H OCEAN
# 6727        956.0       279.0        15.0001       <1H OCEAN
# 5280       1282.0       516.0         9.5221       <1H OCEAN
# 1079       1371.0       626.0         2.2925          INLAND
# 9247       1564.0       408.0         1.5662          INLAND
# ...           ...         ...            ...             ...
# 19221      1299.0       591.0         3.9261       <1H OCEAN
# 16379      3343.0       643.0         2.5473          INLAND
# 13344      1378.0       268.0         3.0057          INLAND
# 9027       5175.0      2173.0         7.7848      NEAR OCEAN
# 13674       849.0       359.0         3.1607          INLAND
#
#        median_house_value
# 19333            240800.0
# 6727             500001.0
# 5280             500001.0
# 1079              85800.0
# 9247              48000.0
# ...                   ...
# 19221            213300.0
# 16379            106300.0
# 13344             96900.0
# 9027             500001.0
# 13674            138200.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.drop(['ocean_proximity'],axis=1).corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924279           -0.109032     0.043049
# latitude            -0.924279  1.000000            0.011373    -0.035326
# housing_median_age  -0.109032  0.011373            1.000000    -0.356486
# total_rooms          0.043049 -0.035326           -0.356486     1.000000
# total_bedrooms       0.068363 -0.066815           -0.315903     0.930750
# population           0.098655 -0.109144           -0.289672     0.855471
# households           0.054900 -0.071407           -0.297930     0.918910
# median_income       -0.016804 -0.079011           -0.115229     0.194924
# median_house_value  -0.046031 -0.144432            0.106515     0.133519
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.068363    0.098655    0.054900      -0.016804
# latitude                 -0.066815   -0.109144   -0.071407      -0.079011
# housing_median_age       -0.315903   -0.289672   -0.297930      -0.115229
# total_rooms               0.930750    0.855471    0.918910       0.194924
# total_bedrooms            1.000000    0.875188    0.979305      -0.009584
# population                0.875188    1.000000    0.905086       0.002132
# households                0.979305    0.905086    1.000000       0.011407
# median_income            -0.009584    0.002132    0.011407       1.000000
# median_house_value        0.051210   -0.024884    0.065858       0.691620
#
#                     median_house_value
# longitude                    -0.046031
# latitude                     -0.144432
# housing_median_age            0.106515
# total_rooms                   0.133519
# total_bedrooms                0.051210
# population                   -0.024884
# households                    0.065858
# median_income                 0.691620
# median_house_value            1.000000

# %%
plt.pyplot.figure(figsize=(15,8))
sns.heatmap(train_data.drop(['ocean_proximity'],axis=1).corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7223
# INLAND        5225
# NEAR OCEAN    2095
# NEAR BAY      1800
# ISLAND           3
# Name: count, dtype: int64

# %%
# train_data.join(pd.get_dummies(train_data.ocean_proximity))
# train_data
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 19333       True   False   False     False       False
# 6727        True   False   False     False       False
# 5280        True   False   False     False       False
# 1079       False    True   False     False       False
# 9247       False    True   False     False       False
# ...          ...     ...     ...       ...         ...
# 19221       True   False   False     False       False
# 16379      False    True   False     False       False
# 13344      False    True   False     False       False
# 9027       False   False   False     False        True
# 13674      False    True   False     False       False
#
# [16346 rows x 5 columns]

# %%
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19333    -122.72     38.58                 4.0     8.859789        7.003974
# 6727     -118.12     34.12                52.0     7.975221        5.762051
# 5280     -118.48     34.05                48.0     8.195334        6.270988
# 1079     -121.82     39.73                44.0     7.980708        6.492240
# 9247     -120.07     36.97                28.0     7.355002        6.001415
# ...          ...       ...                 ...          ...             ...
# 19221    -122.71     38.46                23.0     8.077447        6.403574
# 16379    -121.30     38.02                16.0     7.907652        6.432940
# 13344    -117.64     34.05                32.0     7.029973        5.529429
# 9027     -118.88     34.02                19.0     9.679781        7.867871
# 13674    -117.27     34.05                34.0     7.440734        5.981414
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 19333    7.985144    6.950815         5.0555            240800.0       True
# 6727     6.863803    5.634790        15.0001            500001.0       True
# 5280     7.156956    6.248043         9.5221            500001.0       True
# 1079     7.224025    6.440947         2.2925             85800.0      False
# 9247     7.355641    6.013715         1.5662             48000.0      False
# ...           ...         ...            ...                 ...        ...
# 19221    7.170120    6.383507         3.9261            213300.0       True
# 16379    8.114923    6.467699         2.5473            106300.0      False
# 13344    7.229114    5.594711         3.0057             96900.0      False
# 9027     8.551788    7.684324         7.7848            500001.0      False
# 13674    6.745236    5.886104         3.1607            138200.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 19333   False   False     False       False
# 6727    False   False     False       False
# 5280    False   False     False       False
# 1079     True   False     False       False
# 9247     True   False     False       False
# ...       ...     ...       ...         ...
# 19221   False   False     False       False
# 16379    True   False     False       False
# 13344    True   False     False       False
# 9027    False   False     False        True
# 13674    True   False     False       False
#
# [16346 rows x 14 columns]

# %%
plt.pyplot.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.pyplot.figure(figsize=(15,8))
sns.scatterplot(x="latitude",y="longitude",data=train_data,hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio']=train_data['total_bedrooms']/train_data['total_rooms']
train_data['household_room']=train_data['total_rooms']/train_data['households']

# %%
plt.pyplot.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
X_train,y_train=train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
model=LinearRegression().fit(X_train,y_train)

# %%
test_data=X_test.join(y_test)

test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['households']=np.log(test_data['households']+1)
test_data=test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

test_data['bedroom_ratio']=test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_room']=test_data['total_rooms']/test_data['households']

test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9900     -122.27     38.29                20.0     8.261268        6.679599
# 11844    -120.92     40.02                35.0     5.950643        4.532599
# 17439    -120.45     34.63                32.0     7.518064        5.736572
# 6691     -118.08     34.13                46.0     7.122060        4.997212
# 2691     -115.52     32.97                10.0     7.539027        5.961005
# ...          ...       ...                 ...          ...             ...
# 18962    -122.05     38.26                21.0     8.881281        7.256297
# 11665    -118.03     33.85                23.0     8.611776        7.040536
# 2348     -119.69     36.80                31.0     7.854381        6.129050
# 9158     -118.44     34.50                 5.0     7.323171        5.398163
# 11802    -121.29     38.89                10.0     6.483107        4.795791
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 9900     7.644441    6.652863         3.3021            152700.0      False
# 11844    5.313206    4.290459         2.6458            102500.0      False
# 17439    6.720220    5.811141         4.5486            172400.0      False
# 6691     5.934894    4.983607         8.4546            500001.0      False
# 2691     7.227662    5.823046         1.9911             67500.0      False
# ...           ...         ...            ...                 ...        ...
# 18962    8.275886    7.228388         3.0912            126300.0      False
# 11665    7.963460    6.912743         3.9156            224100.0       True
# 2348     7.175490    6.037871         3.2813             68700.0      False
# 9158     7.212294    5.375278         8.1344            359000.0      False
# 11802    6.011267    4.990433         3.3889            110800.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_room
# 9900    False   False      True       False       0.808544        1.241761
# 11844    True   False     False       False       0.761699        1.386948
# 17439   False   False     False        True       0.763038        1.293733
# 6691     True   False     False       False       0.701653        1.429098
# 2691     True   False     False       False       0.790686        1.294688
# ...       ...     ...       ...         ...            ...             ...
# 18962    True   False     False       False       0.817033        1.228667
# 11665   False   False     False       False       0.817548        1.245783
# 2348     True   False     False       False       0.780335        1.300853
# 9158     True   False     False       False       0.737135        1.362380
# 11802    True   False     False       False       0.739736        1.299107
#
# [4087 rows x 16 columns]

# %%
X_test,y_test=test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
model.score(X_test,y_test)
# Out:
# 0.6515916136106217

# %%
model.score(X_train,y_train)
# Out:
# 0.6757226822409279
